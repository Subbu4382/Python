# %%
s=input("Enter a string")
if len(s)%2==0:
    vowels="AEIOUaeiou"
    left=s[:len(s)//2]
    right=s[len(s)//2:]
    countl,countr=0,0
    print(countl,countr)
    for i in left:
        if i in vowels:
            countl+=1
    for j in right:
        if j in vowels:
            countr+=1
    print(countl,countr)
    if countl==countr:
        print("True")
    else:
        print("false")
else:
    print("string must be even")

#---------------------------------------------

def equal(s):
    vowels="AEIOUaeiou"
    left=s[:len(s)//2]
    right=s[len(s)//2:]
    countl,countr=0,0
    return sum(c in vowels for c in left)==sum(c in vowels for c in right)
equal("rebels")
# Out:
# 0 0
# 1 1
# True
# True

# %%
l=[123,344,323,34,38,121,2382]
res=[]
count=0
for i in l:
    num=str(i)
    start=num[0]
    end=num[-1]
    if start==end:
        res.append(int(num))
        count+=1
print(res,count)
# Out:
# [323, 121, 2382] 3
